# %% [markdown]
# ### Data Store
# ---
# ** Text File Format **
# - CSV( comma separated values)
# - JSON( Javascript Object Notation)
#
# ** Binary File Format**
# - Sqlite(Relational Database)
# - HDF5 (Object Store)

# %%
import csv

# %%
csvfile = open('../Data/Pokemon.csv','r')

# %%
csvfile
# Out:
# <_io.TextIOWrapper name='../Data/Pokemon.csv' mode='r' encoding='cp1252'>

# %%
csvfile.read()
# Out:
# "#,Name,Type 1,Type 2,Total,HP,Attack,Defense,Sp. Atk,Sp. Def,Speed,Generation,Legendary\n1,Bulbasaur,Grass,Poison,318,45,49,49,65,65,45,1,False\n2,Ivysaur,Grass,Poison,405,60,62,63,80,80,60,1,False\n3,Venusaur,Grass,Poison,525,80,82,83,100,100,80,1,False\n3,VenusaurMega Venusaur,Grass,Poison,625,80,100,123,122,120,80,1,False\n4,Charmander,Fire,,309,39,52,43,60,50,65,1,False\n5,Charmeleon,Fire,,405,58,64,58,80,65,80,1,False\n6,Charizard,Fire,Flying,534,78,84,78,109,85,100,1,False\n6,CharizardMega Charizard X,Fire,Dragon,634,78,130,111,130,85,100,1,False\n6,CharizardMega Charizard Y,Fire,Flying,634,78,104,78,159,115,100,1,False\n7,Squirtle,Water,,314,44,48,65,50,64,43,1,False\n8,Wartortle,Water,,405,59,63,80,65,80,58,1,False\n9,Blastoise,Water,,530,79,83,100,85,105,78,1,False\n9,BlastoiseMega Blastoise,Water,,630,79,103,120,135,115,78,1,False\n10,Caterpie,Bug,,195,45,30,35,20,20,45,1,False\n11,Metapod,Bug,,205,50,20,55,25,25,30,1,False\n12,Butterfree,Bug,Flying,395,60,45,50,90,80,70,1
# ...

# %%
csvfile.read()
# Out:
# ''

# %%
csvfile.seek(0)
# Out:
# 0

# %%
csvfile.read(500)
# Out:
# '#,Name,Type 1,Type 2,Total,HP,Attack,Defense,Sp. Atk,Sp. Def,Speed,Generation,Legendary\n1,Bulbasaur,Grass,Poison,318,45,49,49,65,65,45,1,False\n2,Ivysaur,Grass,Poison,405,60,62,63,80,80,60,1,False\n3,Venusaur,Grass,Poison,525,80,82,83,100,100,80,1,False\n3,VenusaurMega Venusaur,Grass,Poison,625,80,100,123,122,120,80,1,False\n4,Charmander,Fire,,309,39,52,43,60,50,65,1,False\n5,Charmeleon,Fire,,405,58,64,58,80,65,80,1,False\n6,Charizard,Fire,Flying,534,78,84,78,109,85,100,1,False\n6,CharizardMega Chariza'

# %%
csvfile.read(500)
# Out:
# 'rd X,Fire,Dragon,634,78,130,111,130,85,100,1,False\n6,CharizardMega Charizard Y,Fire,Flying,634,78,104,78,159,115,100,1,False\n7,Squirtle,Water,,314,44,48,65,50,64,43,1,False\n8,Wartortle,Water,,405,59,63,80,65,80,58,1,False\n9,Blastoise,Water,,530,79,83,100,85,105,78,1,False\n9,BlastoiseMega Blastoise,Water,,630,79,103,120,135,115,78,1,False\n10,Caterpie,Bug,,195,45,30,35,20,20,45,1,False\n11,Metapod,Bug,,205,50,20,55,25,25,30,1,False\n12,Butterfree,Bug,Flying,395,60,45,50,90,80,70,1,False\n13,Weedle,Bu'

# %%
csvfile.readlines()
# Out:
# ['g,Poison,195,40,35,30,20,20,50,1,False\n',
#  '14,Kakuna,Bug,Poison,205,45,25,50,25,25,35,1,False\n',
#  '15,Beedrill,Bug,Poison,395,65,90,40,45,80,75,1,False\n',
#  '15,BeedrillMega Beedrill,Bug,Poison,495,65,150,40,15,80,145,1,False\n',
#  '16,Pidgey,Normal,Flying,251,40,45,40,35,35,56,1,False\n',
#  '17,Pidgeotto,Normal,Flying,349,63,60,55,50,50,71,1,False\n',
#  '18,Pidgeot,Normal,Flying,479,83,80,75,70,70,101,1,False\n',
#  '18,PidgeotMega Pidgeot,Normal,Flying,579,83,80,80,135,80,121,1,False\n',
#  '19,Rattata,Normal,,253,30,56,35,25,35,72,1,False\n',
#  '20,Raticate,Normal,,413,55,81,60,50,70,97,1,False\n',
#  '21,Spearow,Normal,Flying,262,40,60,30,31,31,70,1,False\n',
#  '22,Fearow,Normal,Flying,442,65,90,65,61,61,100,1,False\n',
#  '23,Ekans,Poison,,288,35,60,44,40,54,55,1,False\n',
#  '24,Arbok,Poison,,438,60,85,69,65,79,80,1,False\n',
#  '25,Pikachu,Electric,,320,35,55,40,50,50,90,1,False\n',
#  '26,Raichu,Electric,,485,60,90,55,90,80,110,1,False\n',
# ...

# %%
csvfile.seek(0)
# Out:
# 0

# %%
csvfile.readline()
# Out:
# '#,Name,Type 1,Type 2,Total,HP,Attack,Defense,Sp. Atk,Sp. Def,Speed,Generation,Legendary\n'

# %%
csvfile.readline()
# Out:
# '1,Bulbasaur,Grass,Poison,318,45,49,49,65,65,45,1,False\n'

# %%
csvfile.readline()
# Out:
# '2,Ivysaur,Grass,Poison,405,60,62,63,80,80,60,1,False\n'

# %%
line=csvfile.readline()

# %%
line
# Out:
# '3,Venusaur,Grass,Poison,525,80,82,83,100,100,80,1,False\n'

# %%
line.strip().split(',')
# Out:
# ['3',
#  'Venusaur',
#  'Grass',
#  'Poison',
#  '525',
#  '80',
#  '82',
#  '83',
#  '100',
#  '100',
#  '80',
#  '1',
#  'False']

# %%
csvfile.close()

# %%
import csv

# %%
with open('../Data/Pokemon.csv','r') as csvfile: 
    reader = csv.reader(csvfile)
    for line in reader: 
        print(line)
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary']
# ['1', 'Bulbasaur', 'Grass', 'Poison', '318', '45', '49', '49', '65', '65', '45', '1', 'False']
# ['2', 'Ivysaur', 'Grass', 'Poison', '405', '60', '62', '63', '80', '80', '60', '1', 'False']
# ['3', 'Venusaur', 'Grass', 'Poison', '525', '80', '82', '83', '100', '100', '80', '1', 'False']
# ['3', 'VenusaurMega Venusaur', 'Grass', 'Poison', '625', '80', '100', '123', '122', '120', '80', '1', 'False']
# ['4', 'Charmander', 'Fire', '', '309', '39', '52', '43', '60', '50', '65', '1', 'False']
# ['5', 'Charmeleon', 'Fire', '', '405', '58', '64', '58', '80', '65', '80', '1', 'False']
# ['6', 'Charizard', 'Fire', 'Flying', '534', '78', '84', '78', '109', '85', '100', '1', 'False']
# ['6', 'CharizardMega Charizard X', 'Fire', 'Dragon', '634', '78', '130', '111', '130', '85', '100', '1', 'False']
# ...

# %%
fieldnames = ['#','Name','Type1','Type2','Total','HP','Attack','Defense','Sp.Atk','Sp.Def','Speed','Generation','Legendary']

# %%
with open('../Data/Pokemon.csv','r') as csvfile: 
    reader = csv.DictReader(csvfile,fieldnames = fieldnames)
    for line in reader: 
        print(line['Name'],line['Type2'])
# Out:
# Name Type 2
# Bulbasaur Poison
# Ivysaur Poison
# Venusaur Poison
# VenusaurMega Venusaur Poison
# Charmander
# Charmeleon
# Charizard Flying
# CharizardMega Charizard X Dragon
# CharizardMega Charizard Y Flying
# Squirtle
# Wartortle
# Blastoise
# BlastoiseMega Blastoise
# Caterpie
# Metapod
# Butterfree Flying
# Weedle Poison
# Kakuna Poison
# Beedrill Poison
# BeedrillMega Beedrill Poison
# Pidgey Flying
# Pidgeotto Flying
# Pidgeot Flying
# PidgeotMega Pidgeot Flying
# Rattata
# Raticate
# Spearow Flying
# Fearow Flying
# Ekans
# Arbok
# Pikachu
# Raichu
# Sandshrew
# Sandslash
# Nidoranâ™€
# Nidorina
# Nidoqueen Ground
# Nidoranâ™‚
# Nidorino
# Nidoking Ground
# Clefairy
# Clefable
# Vulpix
# Ninetales
# Jigglypuff Fairy
# Wigglytuff Fairy
# Zubat Flying
# Golbat Flying
# Oddish Poison
# Gloom Poison
# Vileplume Poison
# Paras Grass
# Parasect Grass
# Venonat Poison
# Venomoth Poison
# Diglett
# Dugtrio
# Meowth
# Persian
# Psyduck
# Golduck
# Mankey
# Primeape
# Growlithe
# ...

# %%
import csv

# %%
import json

# %%
_jsn = {'Name':'Wartortle'}

# %%
_jsn
# Out:
# {'Name': 'Wartortle'}

# %%
json.dumps(_jsn)
# Out:
# '{"Name": "Wartortle"}'

# %%
json.loads('{"Name":"Wartortle"}')
# Out:
# {'Name': 'Wartortle'}

# %%
data = {
    'pokemons': []
}
with open('../Data/Pokemon.csv','r') as csvfile: 
    reader = csv.reader(csvfile)
    for line in reader: 
        data['pokemons'].append(line)

with open('../Data/Pokemon.json','w') as jsonfile:
        json.dump(data,jsonfile)

# %%
jsonfile=open('../Data/Pokemon.json','w')
_jsn = json.load(jsonfile)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-60-fb0ea894e348> in <module>()
#       1 jsonfile=open('../Data/Pokemon.json','w')
# ----> 2 _jsn = json.load(jsonfile)
#
# C:\Users\test\Anaconda3\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     294
#     295     """
# --> 296     return loads(fp.read(),
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
#
# UnsupportedOperation: not readable

# %% [markdown]
# ### Sqlite

# %%
import sqlite3

# %%
conn = sqlite3.connect('../Data/db.sqlite3')

# %%
conn

# %%
cursor = conn.cursor()

# %%
cursor

# %%
sql= """CREATE TABLE pokemons(id INTEGER primary key, atack INTEGER, defense INTEGER, generation INTEGER, hp INTEGER, 
legendary BOOLEAN, name TEXT, sp_atk INTEGER, sp_def INTEGER, speed INTEGER, total INTEGER, type1 TEXT,  type2 TEXT)"""

# %%
cursor.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-17-3e948e25d2e0> in <module>()
# ----> 1 cursor.execute(sql)
#
# OperationalError: table pokemons already exists

# %%
conn.commit()

# %%
sql = '''INSERT INTO pokemons ( id,atack,defense,generation,hp,legendary,name,sp_atk,sp_def,speed,total,type1,typ2)
VALUES(1,49,1,45,0,'Bulbasar',65,65,45,318,'Grass','')'''

# %%
cursor.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-21-3e948e25d2e0> in <module>()
# ----> 1 cursor.execute(sql)
#
# OperationalError: table pokemons has no column named legendary
